# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd

# %%
df = pd.read_csv('all_matches.csv')
# Out:
# C:\Users\samke\AppData\Local\Temp\ipykernel_12792\2722818001.py:1: DtypeWarning: Columns (5,8,10,45,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('all_matches.csv')

# %%
df
# Out:
#          start_date    end_date  location court_surface  prize_money currency
# 0        2012-06-11  2012-06-17  Slovakia          Clay      30000.0        €  \
# 1        2012-06-11  2012-06-17  Slovakia          Clay      30000.0        €
# 2        2012-06-11  2012-06-17  Slovakia          Clay      30000.0        €
# 3        2012-06-11  2012-06-17  Slovakia          Clay      30000.0        €
# 4        2012-06-11  2012-06-17  Slovakia          Clay      30000.0        €
# ...             ...         ...       ...           ...          ...      ...
# 4295822  2010-10-18  2010-10-22       DEN        Carpet          NaN      NaN
# 4295823  2010-10-18  2010-10-22       DEN        Carpet          NaN      NaN
# 4295824  2010-10-18  2010-10-22       DEN        Carpet          NaN      NaN
# 4295825  2010-10-18  2010-10-22       DEN        Carpet          NaN      NaN
# 4295826  2010-10-18  2010-10-22       DEN        Carpet          NaN      NaN
#
#          year                      player_id   player_name
# 0        2012                   adrian-partl      A. Partl  \
# 1        2012                   adrian-partl      A. Partl
# 2        2012                agustin-velotti    A. Velotti
# 3        2012  agustin-velotti_marcel-felder           NaN
# 4        2012           alessandro-giannessi  A. Giannessi
# ...       ...                            ...           ...
# 4295822  2010          tom-georg-hjertonsson           NaN
# 4295823  2010          tom-georg-hjertonsson           NaN
# 4295824  2010                   william-baan           NaN
# 4295825  2010                   william-baan           NaN
# 4295826  2010                   william-baan           NaN
#
#                          opponent_id  ... total_points  duration
# 0                      andrej-martin  ...         88.0  01:02:00  \
# 1                      jozef-kovalik  ...        195.0  02:43:00
# 2                     dominik-hrbaty  ...        126.0  01:17:00
# 3        andrei-daescu_florin-mergea  ...          NaN       NaN
# 4                   harri-heliovaara  ...        194.0  02:32:00
# ...                              ...  ...          ...       ...
# 4295822                axel-helisten  ...          NaN       NaN
# 4295823    karl-eirik-wangensten-oye  ...          NaN       NaN
# 4295824          callum-poland-smith  ...          NaN       NaN
# 4295825              casper-melskens  ...          NaN       NaN
# 4295826                   jelle-sels  ...          NaN       NaN
#
#         player_victory  retirement  seed  won_first_set  doubles  masters
# 0                    f           f   NaN              f        f      100  \
# 1                    t           f   NaN              t        f      100
# 2                    f           f   NaN              f        f      100
# 3                    f           f   NaN              t        t      100
# 4                    t           f     1              t        f      100
# ...                ...         ...   ...            ...      ...      ...
# 4295822              t           f   NaN              t        f        0
# 4295823              f           f   NaN              f        f        0
# 4295824              t           f   NaN              t        f        0
# 4295825              f           f   NaN              f        f        0
# 4295826              t           f   NaN              t        f        0
#
#          round_num    nation
# 0                1  Slovakia
# 1                0  Slovakia
# 2                3  Slovakia
# 3                4  Slovakia
# 4                3  Slovakia
# ...            ...       ...
# 4295822          0       DEN
# 4295823          1       DEN
# 4295824          4       DEN
# 4295825          5       DEN
# 4295826          3       DEN
#
# [4295827 rows x 54 columns]

# %%
df['start_date'] = pd.to_datetime(df['start_date'])

# %%
df = df.sort_values(by='start_date')

# %%
df.head()
# Out:
#         start_date    end_date   location court_surface  prize_money currency
# 2832263 1950-01-21  1950-01-30  Australia          Hard          NaN      NaN  \
# 2832278 1950-01-21  1950-01-30  Australia          Hard          NaN      NaN
# 2832279 1950-01-21  1950-01-30  Australia          Hard          NaN      NaN
# 2832280 1950-01-21  1950-01-30  Australia          Hard          NaN      NaN
# 2832281 1950-01-21  1950-01-30  Australia          Hard          NaN      NaN
# ...            ...         ...        ...           ...          ...      ...
# 2926771 2018-08-22  2018-08-26        AUS          Hard          NaN      NaN
# 2926770 2018-08-22  2018-08-26        AUS          Hard          NaN      NaN
# 2926768 2018-08-22  2018-08-26        AUS          Hard          NaN      NaN
# 2926766 2018-08-22  2018-08-26        AUS          Hard          NaN      NaN
# 2926740 2018-08-22  2018-08-26        AUS          Hard          NaN      NaN
#
#          year              player_id player_name         opponent_id  ...
# 2832263  1950  eric-william-sturgess         NaN      frank-lonergan  ...  \
# 2832278  1950           harry-hopman         NaN  george-worthington  ...
# 2832279  1950           harry-hopman         NaN        keith-rogers  ...
# 2832280  1950              h.-raward         NaN       ian-occleshaw  ...
# 2832281  1950               ian-ayre         NaN        ken-mcgregor  ...
# ...       ...                    ...         ...                 ...  ...
# 2926771  2018            dane-sweeny         NaN           kelvin-du  ...
# 2926770  2018            dane-sweeny         NaN              jin-gu  ...
# 2926768  2018           cooper-white         NaN   shuannon-tricerri  ...
# 2926766  2018         connor-johnson         NaN   shuannon-tricerri  ...
# 2926740  2018           alex-carroll         NaN        man-san-chan  ...
#
#         total_points duration player_victory  retirement  seed  won_first_set
# 2832263          NaN      NaN              t           f     2              t  \
# 2832278          NaN      NaN              f           f   NaN              t
# 2832279          NaN      NaN              t           f   NaN              t
# 2832280          NaN      NaN              f           f   NaN              f
# 2832281          NaN      NaN              f           f   NaN              f
# ...              ...      ...            ...         ...   ...            ...
# 2926771          NaN      NaN              t         NaN     1              t
# 2926770          NaN      NaN              t         NaN     1              t
# 2926768          NaN      NaN              f         NaN   NaN              t
# 2926766          NaN      NaN              t         NaN   NaN              f
# 2926740          NaN      NaN              t         NaN   NaN              t
#
#          doubles  masters  round_num     nation
# 2832263        f     2000          3  Australia
# 2832278        f     2000          4  Australia
# 2832279        f     2000          3  Australia
# 2832280        f     2000          2  Australia
# 2832281        f     2000          3  Australia
# ...          ...      ...        ...        ...
# 2926771        f        0          3        AUS
# 2926770        f        0          4        AUS
# 2926768        f        0          3        AUS
# 2926766        f        0          4        AUS
# 2926740        f        0          2        AUS
#
# [4295827 rows x 54 columns]
